# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("social_network_ads.csv")

# %%
data
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
data = pd.get_dummies(data, drop_first=True)

# %%
cov_matrix = data.cov()

# %%
import seaborn as sns

# %%
hisplot =sns.histplot(data['Age'], bins=30, kde=True, color="blue",alpha = 0.3)
for i in hisplot.containers:
    hisplot.bar_label(i,)
plt.show()

# %%
histplot1 =sns.histplot(data['EstimatedSalary'], bins=30, kde=True, color='red',alpha = 0.3)
for i in histplot1.containers:
    histplot1.bar_label(i,)
plt.show()

# %%
from scipy.stats import skew 
skewness = skew(data['Age'])

# %%
print(skewness)
# Out:
# 0.23046904236325927

# %%
from scipy.stats import skew 
skewness = skew(data['EstimatedSalary'])

# %%
print(skewness)
# Out:
# 0.49316535320478544

# %%
data['Purchased'].count()
# Out:
# 400

# %%
countplot = sns.countplot(x='Purchased',data = data )
for i in countplot.containers:
    countplot.bar_label(i,)
plt.show()

# %%
countplot = sns.countplot(x='Purchased',hue ='Gender',platte='twillight',data=data)
for i in countplot.containers:
    countplot.bar_label(i,)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 countplot = sns.countplot(x='Purchased',hue ='Gender',platte='twillight',data=data)
#       2 for i in countplot.containers:
#       3     countplot.bar_label(i,)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1586, in _BarPlotter.plot(self, ax, bar_kws)
#    1584 def plot(self, ax, bar_kws):
#    1585     """Make the plot."""
# -> 1586     self.draw_bars(ax, bar_kws)
#    1587     self.annotate_axes(ax)
#    1588     if self.orient == "h":
#
# ...
